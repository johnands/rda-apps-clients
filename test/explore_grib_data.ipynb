# %%
import src.python.rdams_client as rc

# %%
print(rc.query.__doc__)
# Out:
# Perform a query based on command line like arguments.
#
#     Args:
#         args (list): argument list of querying commands.
#
#     Returns:
#         (dict): Output of json decoded API query.
#
#     Example:
#         ```
#         >>> query(['-get_status', '123456'])
#
#         >>> query(['-get_metadata', 'ds083.2'])
#         ```

# %%
# Let's see what query can do.
try:
    print(rc.query(['-h']))
except SystemExit: # No pesky system exits while learning.
    pass
# Out:
# usage: rdams [-h] [-print]
#              (-get_summary <dsid> | -get_metadata <dsid> | -get_param_summary <dsid> | -submit <control file> | -get_status [<Request Index>] | -download <Request Index> | -get_filelist <Request Index> | -globus_download <Request Index> | -get_control_file_template <dsid> | -purge <Request Index>)
#
# Queries NCAR RDA REST API.
#
# options:
#   -h, --help            show this help message and exit
#   -print, -p            Do not print result of queries.
#   -get_summary <dsid>, -gsum <dsid>
#                         Get a summary of the given dataset.
#   -get_metadata <dsid>, -gm <dsid>
#                         Get metadata for a given dataset.
#   -get_param_summary <dsid>, -gpm <dsid>
#                         Get only parameters for a given dataset.
#   -submit <control file>, -s <control file>
#                         Submit a request using a control file.
#   -get_status [<Request Index>], -gs [<Request Index>]
#                         Get a summary of the given dataset.
#   -download <Request Index>, -d <Request Index>
#                         Download data given a request id.
#   -get_filelist <Request Index>, -gf <Request Index>
#                         Query the filelist for a completed request.
#   -globus_download <Request Index>, -gd <Request Index>
#                         Start a globus transfer for a give request index.
#   -get_control_file_template <dsid>, -gt <dsid>
#                         Get a template control file used for subsetting.
#   -purge <Request Index>
#                         Purge a request.

# %%
dataset_id = 'ds084.1'
rc.get_summary(dataset_id)
# Out:
# {'http_response': 200,
#  'error_messages': [],
#  'data': {'subsetting_available': True,
#   'data': [{'request_type': 'T', 'group_index': 0}]},
#  'contact': 'rdahelp@ucar.edu'}

# %%
param_response = rc.query(['-get_param_summary', dataset_id])
param_data = param_response['data']['data']
params = list(map(lambda x: x['param_description'], param_data))
print('\n'.join(params))
# Out:
# Temperature
# Potential temperature
# Apparent temperature
# Dewpoint temperature
# Specific humidity
# Relative humidity
# Snow depth
# Water equivalent of accumulated snow depth
# Categorical rain (yes=1; no=0)
# Categorical freezing rain (yes=1; no=0)
# Categorical ice pellets (yes=1; no=0)
# Categorical snow (yes=1; no=0)
# Potential evaporation rate
# Cloud water mixing ratio
# Ice water mixing ratio
# Rain water mixing ratio
# Snow water mixing ratio
# Precipitable water
# Graupel
# Convective precipitation rate
# Percent frozen precipitation
# Precipitation rate
# Total ozone
# Ozone mixing ratio
# Derived radar reflectivity
# Maximum/Composite radar reflectivity
# Visibility
# Absolute vorticity
# Vertical speed shear
# u-component of storm motion
# v-component of storm motion
# Frictional velocity
# u-component of wind
# Wind speed (gust)
# Ventilation rate
# v-component of wind
# Vertical velocity (pressure)
# Vertical velocity (geometric)
# Pressure
# Pressure reduced to MSL
# MSLP (Eta model reduction)
# Planetary boundary layer height
# Pressure of level from which parcel was lifted
# ICAO standard atmosphere reference height
# Geopotential height
# Total cloud cover
# Sunshine duration
# Low cloud cover
# Medium cloud cover
# High cloud cover
# Cloud water
# Surface lifted index
# Best (4 layer) lifted index
# Convective available potential energy
# Convective inhibition
# Storm relative helicity
# Ice cover
# Ice thickness
# Ice growth rate
# Ice temperature
# Land cover (0=sea, 1=land)
# Surface roughness
# Volumetric soil moisture content
# Plant canopy surface water
# Soil temperature
# Wilting point
# Vegetation
# Soil type
# Liquid volumetric soil moisture (non-frozen)
# Field capacity
# Haines index
# Temperature
# Latent heat flux
# Sensible heat flux
# Categorical rain (yes=1; no=0)
# Categorical freezing rain (yes=1; no=0)
# Categorical ice pellets (yes=1; no=0)
# Categorical snow (yes=1; no=0)
# Convective precipitation rate
# Precipitation rate
# Albedo
# Momentum flux, u-component
# Momentum flux, v-component
# Pressure
# Zonal flux of gravity wave stress
# Meridional flux of gravity wave stress
# Downward shortwave radiation flux
# Upward shortwave radiation flux
# Downward longwave radiation flux
# Upward longwave radiation flux
# Total cloud cover
# Cloud workfunction
# Low cloud cover
# Medium cloud cover
# High cloud cover
# Ground heat flux
# Convective precipitation
# Total precipitation
# Convective precipitation
# Total precipitation
# Water runoff
# Minimum temperature
# Maximum temperature

# %%
param_map = {}
for _param in param_data:
    long_name = _param['param_description']
    short_name = _param['param']
    param_map[long_name] = short_name

for k,v in param_map.items(): print('{:7} : {}'.format(v, k))
# Out:
# TMP     : Temperature
# POT     : Potential temperature
# APTMP   : Apparent temperature
# DPT     : Dewpoint temperature
# SPF H   : Specific humidity
# R H     : Relative humidity
# SNO D   : Snow depth
# WEASD   : Water equivalent of accumulated snow depth
# CRAIN   : Categorical rain (yes=1; no=0)
# CFRZR   : Categorical freezing rain (yes=1; no=0)
# CICEP   : Categorical ice pellets (yes=1; no=0)
# CSNOW   : Categorical snow (yes=1; no=0)
# PEVPR   : Potential evaporation rate
# CLWMR   : Cloud water mixing ratio
# ICMR    : Ice water mixing ratio
# RWMR    : Rain water mixing ratio
# SNMR    : Snow water mixing ratio
# P WAT   : Precipitable water
# GRLE    : Graupel
# CPRAT   : Convective precipitation rate
# CPOFP   : Percent frozen precipitation
# PRATE   : Precipitation rate
# TOZNE   : Total ozone
# O3MR    : Ozone mixing ratio
# REFD    : Derived radar reflectivity
# REFC    : Maximum/Composite radar reflectivity
# VIS     : Visibility
# ABS V   : Absolute vorticity
# VW SH   : Vertical speed shear
# USTM    : u-component of storm motion
# VSTM    : v-component of storm motion
# FRICV   : Frictional velocity
# U GRD   : u-component of wind
# GUST    : Wind speed (gust)
# VRATE   : Ventilation rate
# V GRD   : v-component of wind
# V VEL   : Vertical velocity (pressure)
# DZDT    : Vertical velocity (geometric)
# PRES    : Pressure
# PRMSL   : Pressure reduced to MSL
# MSLET   : MSLP (Eta model reduction)
# HPBL    : Planetary boundary layer height
# PLPL    : Pressure of level from which parcel was lifted
# ICAHT   : ICAO standard atmosphere reference height
# HGT     : Geopotential height
# T CDC   : Total cloud cover
# SUNSD   : Sunshine duration
# L CDC   : Low cloud cover
# M CDC   : Medium cloud cover
# H CDC   : High cloud cover
# C WAT   : Cloud water
# LFT X   : Surface lifted index
# 4LFTX   : Best (4 layer) lifted index
# CAPE    : Convective available potential energy
# CIN     : Convective inhibition
# HLCY    : Storm relative helicity
# ICEC    : Ice cover
# ICETK   : Ice thickness
# ICEG    : Ice growth rate
# ICETMP  : Ice temperature
# LAND    : Land cover (0=sea, 1=land)
# SFC R   : Surface roughness
# SOILW   : Volumetric soil moisture content
# CNWAT   : Plant canopy surface water
# TSOIL   : Soil temperature
# WILT    : Wilting point
# VEG     : Vegetation
# SOTYP   : Soil type
# SOILL   : Liquid volumetric soil moisture (non-frozen)
# FLDCP   : Field capacity
# HINDEX  : Haines index
# LHTFL   : Latent heat flux
# SHTFL   : Sensible heat flux
# ALBDO   : Albedo
# U FLX   : Momentum flux, u-component
# V FLX   : Momentum flux, v-component
# U-GWD   : Zonal flux of gravity wave stress
# V-GWD   : Meridional flux of gravity wave stress
# DSWRF   : Downward shortwave radiation flux
# USWRF   : Upward shortwave radiation flux
# DLWRF   : Downward longwave radiation flux
# ULWRF   : Upward longwave radiation flux
# CWORK   : Cloud workfunction
# GFLUX   : Ground heat flux
# ACPCP   : Convective precipitation
# A PCP   : Total precipitation
# WATR    : Water runoff
# T MIN   : Minimum temperature
# T MAX   : Maximum temperature

# %%
param_response
# Out:
# {'http_response': 200,
#  'error_messages': [],
#  'data': {'subsetting_available': True,
#   'dsid': '084.1',
#   'data': [{'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'TMP',
#     'param_description': 'Temperature',
#     'standard_name': 'air_temperature',
#     'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'POT',
#     'param_description': 'Potential temperature',
#     'standard_name': 'air_potential_temperature',
#     'GCMD_uuid': 'RDAf08d0-6b2d-7ffe-ddad-ce812cf2556c'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'APTMP',
#     'param_description': 'Apparent temperature'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'DPT',
#     'param_description': 'Dewpoint temperature',
#     'standard_name': 'dew_point_temperature',
#     'GCMD_uuid': '731beb11-9418-40ec-8f2c-c4b320e8231a'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SPF H',
#     'param_description': 'Specific humidity',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'specific_humidity'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'R H',
#     'param_description': 'Relative humidity',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'relative_humidity'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SNO D',
#     'param_description': 'Snow depth',
#     'GCMD_uuid': '9512b90f-f495-41bb-9600-ff25e4cfc571',
#     'standard_name': 'surface_snow_thickness'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'WEASD',
#     'param_description': 'Water equivalent of accumulated snow depth',
#     'GCMD_uuid': '47d8d3db-9aea-49f3-8edd-5216736a85ef',
#     'standard_name': 'surface_snow_amount'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CRAIN',
#     'param_description': 'Categorical rain (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PEVPR',
#     'param_description': 'Potential evaporation rate',
#     'GCMD_uuid': 'b68ab978-6db6-49ee-84e2-5f37b461a998',
#     'standard_name': 'potential_water_evaporation_flux'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CLWMR',
#     'param_description': 'Cloud water mixing ratio',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICMR',
#     'param_description': 'Ice water mixing ratio',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'RWMR',
#     'param_description': 'Rain water mixing ratio'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SNMR',
#     'param_description': 'Snow water mixing ratio'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'P WAT',
#     'param_description': 'Precipitable water',
#     'GCMD_uuid': 'c3a4eb4a-4619-43cd-b890-b567d01324ea',
#     'standard_name': 'atmosphere_water_vapor_content'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'GRLE',
#     'param_description': 'Graupel'},
#    {'units': 'kg m^-2 s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CPOFP',
#     'param_description': 'Percent frozen precipitation'},
#    {'units': 'kg m^-2 s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux'},
#    {'units': 'Dobson',
#     'native_format': 'WMO_GRIB2',
#     'param': 'TOZNE',
#     'param_description': 'Total ozone'},
#    {'units': 'kg kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'O3MR',
#     'param_description': 'Ozone mixing ratio'},
#    {'units': 'dB',
#     'native_format': 'WMO_GRIB2',
#     'param': 'REFD',
#     'param_description': 'Derived radar reflectivity'},
#    {'units': 'dB',
#     'native_format': 'WMO_GRIB2',
#     'param': 'REFC',
#     'param_description': 'Maximum/Composite radar reflectivity'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'VIS',
#     'param_description': 'Visibility',
#     'GCMD_uuid': '9337898d-68dc-43d7-93a9-6afdb4ab1784'},
#    {'units': 's^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ABS V',
#     'param_description': 'Absolute vorticity',
#     'GCMD_uuid': '858a80ff-5aa4-4590-b2e2-e88a802a6ee4',
#     'standard_name': 'atmosphere_absolute_vorticity'},
#    {'units': 's^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'VW SH',
#     'param_description': 'Vertical speed shear',
#     'GCMD_uuid': '05cf5b56-0f86-4819-b713-1272b97b06c5',
#     'standard_name': 'wind_speed_shear'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'USTM',
#     'param_description': 'u-component of storm motion'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'VSTM',
#     'param_description': 'v-component of storm motion'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'FRICV',
#     'param_description': 'Frictional velocity'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'U GRD',
#     'param_description': 'u-component of wind',
#     'GCMD_uuid': '592d49c4-e8ae-4ab4-bf24-ae4a896d0637',
#     'standard_name': 'eastward_wind'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'GUST',
#     'param_description': 'Wind speed (gust)',
#     'GCMD_uuid': '10685919-bc01-43e7-901a-b62ac44627f3'},
#    {'units': 'm^2 s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'VRATE',
#     'param_description': 'Ventilation rate'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'V GRD',
#     'param_description': 'v-component of wind',
#     'GCMD_uuid': '592d49c4-e8ae-4ab4-bf24-ae4a896d0637',
#     'standard_name': 'northward_wind'},
#    {'units': 'Pa s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'V VEL',
#     'param_description': 'Vertical velocity (pressure)',
#     'GCMD_uuid': '841a7ac7-5981-4e93-895f-1b57c3d892a0',
#     'standard_name': 'lagrangian_tendency_of_air_pressure'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'DZDT',
#     'param_description': 'Vertical velocity (geometric)',
#     'GCMD_uuid': '841a7ac7-5981-4e93-895f-1b57c3d892a0',
#     'standard_name': 'upward_air_velocity'},
#    {'units': 'Pa',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PRES',
#     'param_description': 'Pressure',
#     'GCMD_uuid': 'a5aa7055-642d-4442-9b4b-76a759e15257',
#     'standard_name': 'air_pressure'},
#    {'units': 'Pa',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PRMSL',
#     'param_description': 'Pressure reduced to MSL',
#     'GCMD_uuid': '07ce145c-9936-4675-b4a7-8710e39aa391'},
#    {'units': 'Pa',
#     'native_format': 'WMO_GRIB2',
#     'param': 'MSLET',
#     'param_description': 'MSLP (Eta model reduction)',
#     'GCMD_uuid': '07ce145c-9936-4675-b4a7-8710e39aa391'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'HPBL',
#     'param_description': 'Planetary boundary layer height',
#     'GCMD_uuid': '765e92a7-8c14-47dc-bdd8-d85d132a11ee'},
#    {'units': 'Pa',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PLPL',
#     'param_description': 'Pressure of level from which parcel was lifted'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICAHT',
#     'param_description': 'ICAO standard atmosphere reference height'},
#    {'units': 'gpm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'HGT',
#     'param_description': 'Geopotential height',
#     'GCMD_uuid': 'd6aec072-daf9-4f96-b667-6c7831cf6bdd',
#     'standard_name': 'geopotential_height'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'T CDC',
#     'param_description': 'Total cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': 's',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SUNSD',
#     'param_description': 'Sunshine duration'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'L CDC',
#     'param_description': 'Low cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'M CDC',
#     'param_description': 'Medium cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'H CDC',
#     'param_description': 'High cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'C WAT',
#     'param_description': 'Cloud water',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97'},
#    {'units': 'deg K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'LFT X',
#     'param_description': 'Surface lifted index'},
#    {'units': 'deg K',
#     'native_format': 'WMO_GRIB2',
#     'param': '4LFTX',
#     'param_description': 'Best (4 layer) lifted index'},
#    {'units': 'J kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CAPE',
#     'param_description': 'Convective available potential energy'},
#    {'units': 'J kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CIN',
#     'param_description': 'Convective inhibition'},
#    {'units': 'm^2 s^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'HLCY',
#     'param_description': 'Storm relative helicity'},
#    {'units': 'fraction',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICEC',
#     'param_description': 'Ice cover',
#     'GCMD_uuid': '87feb47e-aee3-42f1-8c39-5109d9d5422e'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICETK',
#     'param_description': 'Ice thickness',
#     'GCMD_uuid': 'a735d8ca-182c-4307-9305-186a065e84a4'},
#    {'units': 'm s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICEG',
#     'param_description': 'Ice growth rate',
#     'GCMD_uuid': '89fc22ca-326e-468c-ad3d-171c4ad34977'},
#    {'units': 'deg K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ICETMP',
#     'param_description': 'Ice temperature',
#     'GCMD_uuid': 'f6e7aa9a-ae65-480e-84fa-b3a5d523e822'},
#    {'units': 'Proportion',
#     'native_format': 'WMO_GRIB2',
#     'param': 'LAND',
#     'param_description': 'Land cover (0=sea, 1=land)',
#     'GCMD_uuid': '5066def0-b14b-4a2c-b40f-dc9953860366'},
#    {'units': 'm',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SFC R',
#     'param_description': 'Surface roughness',
#     'GCMD_uuid': '21474df3-f9a6-48ca-be15-bdb3611fe062'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'SOILW',
#     'param_description': 'Volumetric soil moisture content',
#     'GCMD_uuid': 'bbe2ea34-8842-4a9f-9b0b-95dd3c71857f'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CNWAT',
#     'param_description': 'Plant canopy surface water'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'TSOIL',
#     'param_description': 'Soil temperature',
#     'GCMD_uuid': '0546b91a-294d-45d9-8b45-76aaad0cc024'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'WILT',
#     'param_description': 'Wilting point'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'VEG',
#     'param_description': 'Vegetation',
#     'GCMD_uuid': '5bdb3251-4811-439c-b172-9bbcd98e84b3'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'SOTYP',
#     'param_description': 'Soil type',
#     'GCMD_uuid': '14e51b6e-9d91-4af5-bb93-22842359d492'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'SOILL',
#     'param_description': 'Liquid volumetric soil moisture (non-frozen)',
#     'GCMD_uuid': 'bbe2ea34-8842-4a9f-9b0b-95dd3c71857f'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'FLDCP',
#     'param_description': 'Field capacity'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'HINDEX',
#     'param_description': 'Haines index'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'TMP',
#     'param_description': 'Temperature',
#     'standard_name': 'air_temperature',
#     'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'LHTFL',
#     'param_description': 'Latent heat flux',
#     'GCMD_uuid': '46a3c823-727d-4c3c-b09d-e3e3fcaa43a5'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'SHTFL',
#     'param_description': 'Sensible heat flux',
#     'GCMD_uuid': '46a3c823-727d-4c3c-b09d-e3e3fcaa43a5'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CRAIN',
#     'param_description': 'Categorical rain (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)'},
#    {'native_format': 'WMO_GRIB2',
#     'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)'},
#    {'units': 'kg m^-2 s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux'},
#    {'units': 'kg m^-2 s^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ALBDO',
#     'param_description': 'Albedo',
#     'GCMD_uuid': '136b1de3-4b2e-49e6-80cd-cf2e9bac2c48'},
#    {'units': 'N m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'U FLX',
#     'param_description': 'Momentum flux, u-component',
#     'standard_name': 'downward_eastward_momentum_flux_in_air'},
#    {'units': 'N m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'V FLX',
#     'param_description': 'Momentum flux, v-component',
#     'standard_name': 'downward_northward_momentum_flux_in_air'},
#    {'units': 'Pa',
#     'native_format': 'WMO_GRIB2',
#     'param': 'PRES',
#     'param_description': 'Pressure',
#     'GCMD_uuid': 'a5aa7055-642d-4442-9b4b-76a759e15257',
#     'standard_name': 'air_pressure'},
#    {'units': 'N m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'U-GWD',
#     'param_description': 'Zonal flux of gravity wave stress',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf'},
#    {'units': 'N m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'V-GWD',
#     'param_description': 'Meridional flux of gravity wave stress',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'DSWRF',
#     'param_description': 'Downward shortwave radiation flux',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'USWRF',
#     'param_description': 'Upward shortwave radiation flux',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'DLWRF',
#     'param_description': 'Downward longwave radiation flux',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ULWRF',
#     'param_description': 'Upward longwave radiation flux',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'T CDC',
#     'param_description': 'Total cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': 'J kg^-1',
#     'native_format': 'WMO_GRIB2',
#     'param': 'CWORK',
#     'param_description': 'Cloud workfunction'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'L CDC',
#     'param_description': 'Low cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'M CDC',
#     'param_description': 'Medium cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': '%',
#     'native_format': 'WMO_GRIB2',
#     'param': 'H CDC',
#     'param_description': 'High cloud cover',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702'},
#    {'units': 'W m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'GFLUX',
#     'param_description': 'Ground heat flux',
#     'GCMD_uuid': '46a3c823-727d-4c3c-b09d-e3e3fcaa43a5'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount'},
#    {'units': 'kg m^-2',
#     'native_format': 'WMO_GRIB2',
#     'param': 'WATR',
#     'param_description': 'Water runoff',
#     'GCMD_uuid': 'f6a54329-486b-4d5f-b105-c639cec42351'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'T MIN',
#     'param_description': 'Minimum temperature',
#     'standard_name': 'minimum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754'},
#    {'units': 'K',
#     'native_format': 'WMO_GRIB2',
#     'param': 'T MAX',
#     'param_description': 'Maximum temperature',
#     'standard_name': 'maximum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754'}]},
#  'contact': 'rdahelp@ucar.edu'}

# %%
metadata_response = rc.query(['-get_metadata', dataset_id])

# %%
metadata_response
# Out:
# {'http_response': 200,
#  'error_messages': [],
#  'data': {'subsetting_available': True,
#   'dsid': '084.1',
#   'data': [{'param': 'TMP',
#     'param_description': 'Temperature',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'air_temperature',
#     'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0', 'level_description': 'Tropopause', 'level': 'TRO'},
#      {'level_value': '0',
#       'level_description': 'Maximum wind level',
#       'level': 'MWSL'},
#      {'units': 'm',
#       'level_value': '1829',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': 'm',
#       'level_value': '2743',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': 'm',
#       'level_value': '3658',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#       'level_value': '2000',
#       'level_description': 'Potential vorticity surface',
#       'level': 'PVL'},
#      {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#       'level_value': '-2000',
#       'level_description': 'Potential vorticity surface',
#       'level': 'PVL'},
#      {'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '80',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'm',
#       'level_value': '100',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'POT',
#     'param_description': 'Potential temperature',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'air_potential_temperature',
#     'GCMD_uuid': 'RDAf08d0-6b2d-7ffe-ddad-ce812cf2556c',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'}]},
#    {'param': 'APTMP',
#     'param_description': 'Apparent temperature',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'DPT',
#     'param_description': 'Dewpoint temperature',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'dew_point_temperature',
#     'GCMD_uuid': '731beb11-9418-40ec-8f2c-c4b320e8231a',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'SPF H',
#     'param_description': 'Specific humidity',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'specific_humidity',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '80',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'R H',
#     'param_description': 'Relative humidity',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'relative_humidity',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'},
#      {'level_value': '0',
#       'level_description': 'Level of 0-degree C isotherm',
#       'level': '0DEG'},
#      {'level_value': '0',
#       'level_description': 'Highest tropospheric freezing level',
#       'level': 'HTFL'},
#      {'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'level_value': '1,0.44',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '0.94,0.72',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '0.72,0.44',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '1,0.33',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'SNO D',
#     'param_description': 'Snow depth',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'm',
#     'GCMD_uuid': '9512b90f-f495-41bb-9600-ff25e4cfc571',
#     'standard_name': 'surface_snow_thickness',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'WEASD',
#     'param_description': 'Water equivalent of accumulated snow depth',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': '47d8d3db-9aea-49f3-8edd-5216736a85ef',
#     'standard_name': 'surface_snow_amount',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CRAIN',
#     'param_description': 'Categorical rain (yes=1; no=0)',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PEVPR',
#     'param_description': 'Potential evaporation rate',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'b68ab978-6db6-49ee-84e2-5f37b461a998',
#     'standard_name': 'potential_water_evaporation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CLWMR',
#     'param_description': 'Cloud water mixing ratio',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'ICMR',
#     'param_description': 'Ice water mixing ratio',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'RWMR',
#     'param_description': 'Rain water mixing ratio',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'SNMR',
#     'param_description': 'Snow water mixing ratio',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'P WAT',
#     'param_description': 'Precipitable water',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'c3a4eb4a-4619-43cd-b890-b567d01324ea',
#     'standard_name': 'atmosphere_water_vapor_content',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'GRLE',
#     'param_description': 'Graupel',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CPOFP',
#     'param_description': 'Percent frozen precipitation',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'TOZNE',
#     'param_description': 'Total ozone',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'Dobson',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'O3MR',
#     'param_description': 'Ozone mixing ratio',
#     'start_date': 202311041200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
# ...
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ALBDO',
#     'param_description': 'Albedo',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': '136b1de3-4b2e-49e6-80cd-cf2e9bac2c48',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'U FLX',
#     'param_description': 'Momentum flux, u-component',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'standard_name': 'downward_eastward_momentum_flux_in_air',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'V FLX',
#     'param_description': 'Momentum flux, v-component',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'standard_name': 'downward_northward_momentum_flux_in_air',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRES',
#     'param_description': 'Pressure',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'Pa',
#     'GCMD_uuid': 'a5aa7055-642d-4442-9b4b-76a759e15257',
#     'standard_name': 'air_pressure',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Middle cloud bottom level',
#       'level': 'MCBL'},
#      {'level_value': '0',
#       'level_description': 'Middle cloud top level',
#       'level': 'MCTL'},
#      {'level_value': '0',
#       'level_description': 'High cloud bottom level',
#       'level': 'HCBL'},
#      {'level_value': '0',
#       'level_description': 'Low cloud top level',
#       'level': 'LCTL'},
#      {'level_value': '0',
#       'level_description': 'High cloud top level',
#       'level': 'HCTL'},
#      {'level_value': '0',
#       'level_description': 'Low cloud bottom level',
#       'level': 'LCBL'}]},
#    {'param': 'U-GWD',
#     'param_description': 'Zonal flux of gravity wave stress',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'V-GWD',
#     'param_description': 'Meridional flux of gravity wave stress',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'DSWRF',
#     'param_description': 'Downward shortwave radiation flux',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'USWRF',
#     'param_description': 'Upward shortwave radiation flux',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0',
#       'level_description': 'Nominal top of atmosphere',
#       'level': 'NTAT'}]},
#    {'param': 'DLWRF',
#     'param_description': 'Downward longwave radiation flux',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ULWRF',
#     'param_description': 'Upward longwave radiation flux',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0',
#       'level_description': 'Nominal top of atmosphere',
#       'level': 'NTAT'}]},
#    {'param': 'T CDC',
#     'param_description': 'Total cloud cover',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Boundary layer cloud layer',
#       'level': 'BCY'},
#      {'level_value': '0',
#       'level_description': 'Entire atmosphere',
#       'level': 'EATM'}]},
#    {'param': 'CWORK',
#     'param_description': 'Cloud workfunction',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'J kg^-1',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'L CDC',
#     'param_description': 'Low cloud cover',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Low cloud layer',
#       'level': 'LCY'}]},
#    {'param': 'M CDC',
#     'param_description': 'Medium cloud cover',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Middle cloud layer',
#       'level': 'MCY'}]},
#    {'param': 'H CDC',
#     'param_description': 'High cloud cover',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'High cloud layer',
#       'level': 'HCY'}]},
#    {'param': 'GFLUX',
#     'param_description': 'Ground heat flux',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '46a3c823-727d-4c3c-b09d-e3e3fcaa43a5',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'start_date': 202310191200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount',
#     'product': '384-hour Accumulation (initial+0 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'start_date': 202310191200,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount',
#     'product': '384-hour Accumulation (initial+0 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'WATR',
#     'param_description': 'Water runoff',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'f6a54329-486b-4d5f-b105-c639cec42351',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'T MIN',
#     'param_description': 'Minimum temperature',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'minimum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754',
#     'product': '6-hour Minimum (initial+378 to initial+384)',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'T MAX',
#     'param_description': 'Maximum temperature',
#     'start_date': 202311040600,
#     'end_date': 202311041200,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'maximum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754',
#     'product': '6-hour Maximum (initial+378 to initial+384)',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]}]},
#  'contact': 'rdahelp@ucar.edu'}

# %%
metadata = metadata_response['data']['data']
temperature_vars = list(filter(lambda x: x['param'] == 'TMP', metadata))
temperature_vars
# Out:
# [{'param': 'TMP',
#   'param_description': 'Temperature',
#   'start_date': 202311021800,
#   'end_date': 202311021800,
#   'native_format': 'WMO_GRIB2',
#   'gridproj': 'latLon',
#   'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#   'level': None,
#   'units': 'K',
#   'standard_name': 'air_temperature',
#   'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac',
#   'product': '384-hour Forecast',
#   'levels': [{'units': 'mbar',
#     'level_value': '1000',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '975',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '950',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '925',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '900',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '850',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '800',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '750',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '700',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '650',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '600',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '550',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '500',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '450',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '400',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '350',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '300',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '250',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '200',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '150',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '100',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '70',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '50',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '30',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '20',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '10',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'level_value': '0',
#     'level_description': 'Ground or water surface',
#     'level': 'SFC'},
#    {'level_value': '0', 'level_description': 'Tropopause', 'level': 'TRO'},
#    {'level_value': '0',
#     'level_description': 'Maximum wind level',
#     'level': 'MWSL'},
#    {'units': 'm',
#     'level_value': '1829',
#     'level_description': 'Specified altitude above mean sea level',
#     'level': 'GPML'},
#    {'units': 'm',
#     'level_value': '2743',
#     'level_description': 'Specified altitude above mean sea level',
#     'level': 'GPML'},
#    {'units': 'm',
#     'level_value': '3658',
#     'level_description': 'Specified altitude above mean sea level',
#     'level': 'GPML'},
#    {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#     'level_value': '2000',
#     'level_description': 'Potential vorticity surface',
#     'level': 'PVL'},
#    {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#     'level_value': '-2000',
#     'level_description': 'Potential vorticity surface',
#     'level': 'PVL'},
#    {'level_value': '0.995',
#     'level_description': 'Sigma level',
#     'level': 'SIGL'},
#    {'units': 'm',
#     'level_value': '2',
#     'level_description': 'Specified height above ground',
#     'level': 'HTGL'},
#    {'units': 'mbar',
#     'level_value': '5',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '2',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '1',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0,30',
#     'level_description': 'Level at specified pressure difference from ground to level',
#     'level': 'SPDL'},
#    {'units': 'mbar',
#     'level_value': '3',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '7',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'm',
#     'level_value': '80',
#     'level_description': 'Specified height above ground',
#     'level': 'HTGL'},
#    {'units': 'm',
#     'level_value': '100',
#     'level_description': 'Specified height above ground',
#     'level': 'HTGL'},
#    {'units': 'mbar',
#     'level_value': '0.4',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '15',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '40',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.01',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.02',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.04',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.07',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.1',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.2',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'},
#    {'units': 'mbar',
#     'level_value': '0.7',
#     'level_description': 'Isobaric surface',
#     'level': 'ISBL'}]},
#  {'param': 'TMP',
#   'param_description': 'Temperature',
#   'start_date': 202311021200,
#   'end_date': 202311021800,
#   'native_format': 'WMO_GRIB2',
#   'gridproj': 'latLon',
#   'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#   'level': None,
#   'units': 'K',
#   'standard_name': 'air_temperature',
#   'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac',
#   'product': '6-hour Average (initial+378 to initial+384)',
#   'levels': [{'level_value': '0',
#     'level_description': 'Middle cloud top level',
#     'level': 'MCTL'},
#    {'level_value': '0',
#     'level_description': 'Low cloud top level',
#     'level': 'LCTL'},
#    {'level_value': '0',
#     'level_description': 'High cloud top level',
#     'level': 'HCTL'}]}]

# %%
metadata_response
# Out:
# {'http_response': 200,
#  'error_messages': [],
#  'data': {'subsetting_available': True,
#   'dsid': '084.1',
#   'data': [{'param': 'TMP',
#     'param_description': 'Temperature',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'air_temperature',
#     'GCMD_uuid': '926c1b80-6c11-40eb-ae7f-f5bcfdc43fac',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0', 'level_description': 'Tropopause', 'level': 'TRO'},
#      {'level_value': '0',
#       'level_description': 'Maximum wind level',
#       'level': 'MWSL'},
#      {'units': 'm',
#       'level_value': '1829',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': 'm',
#       'level_value': '2743',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': 'm',
#       'level_value': '3658',
#       'level_description': 'Specified altitude above mean sea level',
#       'level': 'GPML'},
#      {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#       'level_value': '2000',
#       'level_description': 'Potential vorticity surface',
#       'level': 'PVL'},
#      {'units': '10^-9 deg K m^2 kg^-1 s^-1',
#       'level_value': '-2000',
#       'level_description': 'Potential vorticity surface',
#       'level': 'PVL'},
#      {'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '80',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'm',
#       'level_value': '100',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'POT',
#     'param_description': 'Potential temperature',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'air_potential_temperature',
#     'GCMD_uuid': 'RDAf08d0-6b2d-7ffe-ddad-ce812cf2556c',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'}]},
#    {'param': 'APTMP',
#     'param_description': 'Apparent temperature',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'DPT',
#     'param_description': 'Dewpoint temperature',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'dew_point_temperature',
#     'GCMD_uuid': '731beb11-9418-40ec-8f2c-c4b320e8231a',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'SPF H',
#     'param_description': 'Specific humidity',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'specific_humidity',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'm',
#       'level_value': '80',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'R H',
#     'param_description': 'Relative humidity',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': '427e5121-a142-41cb-a8e9-a70b7f98eb6a',
#     'standard_name': 'relative_humidity',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'},
#      {'level_value': '0',
#       'level_description': 'Level of 0-degree C isotherm',
#       'level': '0DEG'},
#      {'level_value': '0',
#       'level_description': 'Highest tropospheric freezing level',
#       'level': 'HTFL'},
#      {'level_value': '0.995',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0,30',
#       'level_description': 'Level at specified pressure difference from ground to level',
#       'level': 'SPDL'},
#      {'level_value': '1,0.44',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '0.94,0.72',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '0.72,0.44',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'level_value': '1,0.33',
#       'level_description': 'Sigma level',
#       'level': 'SIGL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'}]},
#    {'param': 'SNO D',
#     'param_description': 'Snow depth',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'm',
#     'GCMD_uuid': '9512b90f-f495-41bb-9600-ff25e4cfc571',
#     'standard_name': 'surface_snow_thickness',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'WEASD',
#     'param_description': 'Water equivalent of accumulated snow depth',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': '47d8d3db-9aea-49f3-8edd-5216736a85ef',
#     'standard_name': 'surface_snow_amount',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CRAIN',
#     'param_description': 'Categorical rain (yes=1; no=0)',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PEVPR',
#     'param_description': 'Potential evaporation rate',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'b68ab978-6db6-49ee-84e2-5f37b461a998',
#     'standard_name': 'potential_water_evaporation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CLWMR',
#     'param_description': 'Cloud water mixing ratio',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'ICMR',
#     'param_description': 'Ice water mixing ratio',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'GCMD_uuid': '05ac9d3e-bc44-41fa-ace0-c41bf3ebee97',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'RWMR',
#     'param_description': 'Rain water mixing ratio',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'SNMR',
#     'param_description': 'Snow water mixing ratio',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'P WAT',
#     'param_description': 'Precipitable water',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'c3a4eb4a-4619-43cd-b890-b567d01324ea',
#     'standard_name': 'atmosphere_water_vapor_content',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'GRLE',
#     'param_description': 'Graupel',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'level_value': '1',
#       'level_description': 'Hybrid level',
#       'level': 'HYBL'}]},
#    {'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CPOFP',
#     'param_description': 'Percent frozen precipitation',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'TOZNE',
#     'param_description': 'Total ozone',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'Dobson',
#     'product': '384-hour Forecast',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'O3MR',
#     'param_description': 'Ozone mixing ratio',
#     'start_date': 202311021800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg kg^-1',
#     'product': '384-hour Forecast',
#     'levels': [{'units': 'mbar',
#       'level_value': '1000',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '975',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '950',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '925',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '900',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '850',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '800',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '750',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '700',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '650',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '600',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '550',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '500',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '450',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '400',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '350',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '300',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '250',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '200',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '150',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '100',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '70',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '50',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '30',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '20',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '10',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '5',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '2',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '3',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '7',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.4',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '15',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '40',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.01',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.02',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.04',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.07',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.1',
#       'level_description': 'Isobaric surface',
#       'level': 'ISBL'},
#      {'units': 'mbar',
#       'level_value': '0.2',
# ...
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CFRZR',
#     'param_description': 'Categorical freezing rain (yes=1; no=0)',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CICEP',
#     'param_description': 'Categorical ice pellets (yes=1; no=0)',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CSNOW',
#     'param_description': 'Categorical snow (yes=1; no=0)',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'CPRAT',
#     'param_description': 'Convective precipitation rate',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'convective_precipitation_flux',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRATE',
#     'param_description': 'Precipitation rate',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2 s^-1',
#     'GCMD_uuid': 'ac50c468-df2f-429c-8394-9d63efcc6f9d',
#     'standard_name': 'precipitation_flux',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ALBDO',
#     'param_description': 'Albedo',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': '136b1de3-4b2e-49e6-80cd-cf2e9bac2c48',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'U FLX',
#     'param_description': 'Momentum flux, u-component',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'standard_name': 'downward_eastward_momentum_flux_in_air',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'V FLX',
#     'param_description': 'Momentum flux, v-component',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'standard_name': 'downward_northward_momentum_flux_in_air',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'PRES',
#     'param_description': 'Pressure',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'Pa',
#     'GCMD_uuid': 'a5aa7055-642d-4442-9b4b-76a759e15257',
#     'standard_name': 'air_pressure',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Middle cloud bottom level',
#       'level': 'MCBL'},
#      {'level_value': '0',
#       'level_description': 'Middle cloud top level',
#       'level': 'MCTL'},
#      {'level_value': '0',
#       'level_description': 'High cloud bottom level',
#       'level': 'HCBL'},
#      {'level_value': '0',
#       'level_description': 'Low cloud top level',
#       'level': 'LCTL'},
#      {'level_value': '0',
#       'level_description': 'High cloud top level',
#       'level': 'HCTL'},
#      {'level_value': '0',
#       'level_description': 'Low cloud bottom level',
#       'level': 'LCBL'}]},
#    {'param': 'U-GWD',
#     'param_description': 'Zonal flux of gravity wave stress',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'V-GWD',
#     'param_description': 'Meridional flux of gravity wave stress',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'N m^-2',
#     'GCMD_uuid': '7e6f7c15-32e7-4b6e-bd35-7bff4bc03caf',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'DSWRF',
#     'param_description': 'Downward shortwave radiation flux',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'USWRF',
#     'param_description': 'Upward shortwave radiation flux',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': 'a8f5c969-34e9-4284-afb5-ff2113f5f881',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0',
#       'level_description': 'Nominal top of atmosphere',
#       'level': 'NTAT'}]},
#    {'param': 'DLWRF',
#     'param_description': 'Downward longwave radiation flux',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ULWRF',
#     'param_description': 'Upward longwave radiation flux',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '68323795-3614-462f-8259-bd5293620799',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'},
#      {'level_value': '0',
#       'level_description': 'Nominal top of atmosphere',
#       'level': 'NTAT'}]},
#    {'param': 'T CDC',
#     'param_description': 'Total cloud cover',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Boundary layer cloud layer',
#       'level': 'BCY'},
#      {'level_value': '0',
#       'level_description': 'Entire atmosphere',
#       'level': 'EATM'}]},
#    {'param': 'CWORK',
#     'param_description': 'Cloud workfunction',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'J kg^-1',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Entire atmosphere (considered as a single layer)',
#       'level': 'EATM'}]},
#    {'param': 'L CDC',
#     'param_description': 'Low cloud cover',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Low cloud layer',
#       'level': 'LCY'}]},
#    {'param': 'M CDC',
#     'param_description': 'Medium cloud cover',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Middle cloud layer',
#       'level': 'MCY'}]},
#    {'param': 'H CDC',
#     'param_description': 'High cloud cover',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': '%',
#     'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'High cloud layer',
#       'level': 'HCY'}]},
#    {'param': 'GFLUX',
#     'param_description': 'Ground heat flux',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'W m^-2',
#     'GCMD_uuid': '46a3c823-727d-4c3c-b09d-e3e3fcaa43a5',
#     'product': '6-hour Average (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'start_date': 202310171800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount',
#     'product': '384-hour Accumulation (initial+0 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'start_date': 202310171800,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount',
#     'product': '384-hour Accumulation (initial+0 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'ACPCP',
#     'param_description': 'Convective precipitation',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'convective_precipitation_amount',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'A PCP',
#     'param_description': 'Total precipitation',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#     'standard_name': 'precipitation_amount',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'WATR',
#     'param_description': 'Water runoff',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'kg m^-2',
#     'GCMD_uuid': 'f6a54329-486b-4d5f-b105-c639cec42351',
#     'product': '6-hour Accumulation (initial+378 to initial+384)',
#     'levels': [{'level_value': '0',
#       'level_description': 'Ground or water surface',
#       'level': 'SFC'}]},
#    {'param': 'T MIN',
#     'param_description': 'Minimum temperature',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'minimum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754',
#     'product': '6-hour Minimum (initial+378 to initial+384)',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]},
#    {'param': 'T MAX',
#     'param_description': 'Maximum temperature',
#     'start_date': 202311021200,
#     'end_date': 202311021800,
#     'native_format': 'WMO_GRIB2',
#     'gridproj': 'latLon',
#     'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#     'level': None,
#     'units': 'K',
#     'standard_name': 'maximum_air_temperature',
#     'GCMD_uuid': '5164162a-60eb-4c94-a0f0-2caaa3bb1754',
#     'product': '6-hour Maximum (initial+378 to initial+384)',
#     'levels': [{'units': 'm',
#       'level_value': '2',
#       'level_description': 'Specified height above ground',
#       'level': 'HTGL'}]}]},
#  'contact': 'rdahelp@ucar.edu'}

# %%
products = set([item['product'] for item in temperature_vars])
products
# Out:
# {'384-hour Forecast', '6-hour Average (initial+378 to initial+384)'}

# %%
selected_hour = list(filter(lambda x: x['product'] == '24-hour Forecast', temperature_vars))

# %%
selected_hour
#assert len(selected_hour) == 1
#selected_hour = selected_hour[0]
#selected_hour['levels']
# Out:
# []

# %%
windu_vars = list(filter(lambda x: x['param'] == 'U GRD', metadata))
products = set([item['product'] for item in windu_vars])
products
# Out:
# {'384-hour Forecast'}

# %%
selected_hour = list(filter(lambda x: x['product'] == '24-hour Forecast', windu_vars))[0]
selected_hour['levels']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 selected_hour = list(filter(lambda x: x['product'] == '24-hour Forecast', windu_vars))[0]
#       2 selected_hour['levels']
#
# IndexError: list index out of range

# %%
solar_vars = list(filter(lambda x: x['param'] == 'DSWRF', metadata))
products = set([item['product'] for item in solar_vars])
products
# Out:
# {'6-hour Average (initial+378 to initial+384)'}

# %%
selected_hour = list(filter(lambda x: x['product'] == '3-hour Average (initial+12 to initial+15)', solar_vars))[0]
selected_hour['levels']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 selected_hour = list(filter(lambda x: x['product'] == '3-hour Average (initial+12 to initial+15)', solar_vars))[0]
#       2 selected_hour['levels']
#
# IndexError: list index out of range

# %%
precip_vars = list(filter(lambda x: x['param'] == 'A PCP', metadata))
products = set([item['product'] for item in precip_vars])
products
# Out:
# {'384-hour Accumulation (initial+0 to initial+384)',
#  '6-hour Accumulation (initial+378 to initial+384)'}

# %%
precip_vars
# Out:
# [{'param': 'A PCP',
#   'param_description': 'Total precipitation',
#   'start_date': 202310171800,
#   'end_date': 202311021800,
#   'native_format': 'WMO_GRIB2',
#   'gridproj': 'latLon',
#   'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#   'level': None,
#   'units': 'kg m^-2',
#   'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#   'standard_name': 'precipitation_amount',
#   'product': '384-hour Accumulation (initial+0 to initial+384)',
#   'levels': [{'level_value': '0',
#     'level_description': 'Ground or water surface',
#     'level': 'SFC'}]},
#  {'param': 'A PCP',
#   'param_description': 'Total precipitation',
#   'start_date': 202311021200,
#   'end_date': 202311021800,
#   'native_format': 'WMO_GRIB2',
#   'gridproj': 'latLon',
#   'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#   'level': None,
#   'units': 'kg m^-2',
#   'GCMD_uuid': 'cad5c02a-e771-434e-bef6-8dced38a68e8',
#   'standard_name': 'precipitation_amount',
#   'product': '6-hour Accumulation (initial+378 to initial+384)',
#   'levels': [{'level_value': '0',
#     'level_description': 'Ground or water surface',
#     'level': 'SFC'}]}]

# %%
selected_hour = list(filter(lambda x: x['product'] == '3-hour Accumulation (initial+12 to initial+15)', precip_vars))[0]
selected_hour['levels']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 selected_hour = list(filter(lambda x: x['product'] == '3-hour Accumulation (initial+12 to initial+15)', precip_vars))[0]
#       2 selected_hour['levels']
#
# IndexError: list index out of range

# %%
mslp_vars = list(filter(lambda x: x['param'] == 'PRMSL', metadata))
products = set([item['product'] for item in mslp_vars])
products
# Out:
# {'384-hour Forecast'}

# %%
selected_hour = list(filter(lambda x: x['product'] == '24-hour Forecast', mslp_vars))[0]
selected_hour['levels']
# Out:
# [{'level_value': '0', 'level_description': 'Mean sea level', 'level': 'MSL'}]

# %%
cloud_cover_vars = list(filter(lambda x: x['param'] == 'H CDC', metadata))
products = set([item['product'] for item in mslp_vars])
products
# Out:
# {'384-hour Forecast'}

# %%
selected_hour = list(filter(lambda x: x['product'] == '384-hour Forecast', cloud_cover_vars))[0]
selected_hour['levels']
# Out:
# [{'level_value': '0', 'level_description': 'High cloud layer', 'level': 'HCY'}]

# %%
response = rc.get_control_file_template(dataset_id)
template = response['data']['template'] # Template string
template_dict = rc.read_control_file(template)
template_dict
# Out:
# {'dataset': 'ds084.1',
#  'date': '201609200000/to/201609200000',
#  'datetype': 'init',
#  'param': 'TMP/R H/ABS V',
#  'level': 'ISBL:850/700/500',
#  'nlat': '30',
#  'slat': '-25',
#  'wlon': '-150',
#  'elon': '-30',
#  'product': 'Analysis/12-hour Forecast/6-hour Forecast/18-hour Forecast',
#  'targetdir': '/glade/scratch'}

# %%
template_dict['param'] = 'TMP'
template_dict['level'] = 'HTGL:2'
template_dict['product'] = '24-hour Forecast'
template_dict['targetdir'] = './data'
template_dict
# Out:
# {'dataset': 'ds084.1',
#  'date': '201609200000/to/201609200000',
#  'datetype': 'init',
#  'param': 'TMP',
#  'level': 'HTGL:2',
#  'nlat': '30',
#  'slat': '-25',
#  'wlon': '-150',
#  'elon': '-30',
#  'product': '24-hour Forecast',
#  'targetdir': './data'}

# %%
response = rc.submit_json(template_dict)
#assert response['code'] == 200
print(response)
# Out:
# {'status': 'ok', 'request_duration': '3.499983 seconds', 'code': 200, 'messages': [], 'result': {'request_id': '552629'}, 'request_end': '2022-03-15T11:28:50.337171', 'request_start': '2022-03-15T11:28:46.837188'}

# %%
import time

def check_ready(rqst_id, wait_interval=120):
    """Checks if a request is ready."""
    for i in range(100): # 100 is arbitrary. Would wait 200 minutes for request
        res = rc.get_status(rqst_id)
        request_status = res['result']['status']
        if request_status == 'Completed':
            return True
        print(request_status)
        print('Not yet available. Waiting ' + str(wait_interval) + ' seconds.' )
        time.sleep(wait_interval)
    return False

# %%
request_id = response['data']['request_id']
check_ready(request_id)
rc.download(request_id)
# Out:
# Downloading gfs.0p25.2016092000.f024.grib2
# 100.000 % Completed
# {'status': 'ok',
#  'request_duration': '0.056345 seconds',
#  'code': 200,
#  'messages': [],
#  'result': {'total_size': 119768,
#   'web_files': [{'web_path': 'https://rda.ucar.edu/dsrqst/STENDE552629/gfs.0p25.2016092000.f024.grib2',
#     'wfile': 'gfs.0p25.2016092000.f024.grib2',
#     'size': 119768}]},
#  'request_end': '2022-03-15T11:31:13.144726',
#  'request_start': '2022-03-15T11:31:13.088381'}

# %%
rc.globus_download(request_id)
