# %%
import pygrib

grib = pygrib.open('data_cache/soil_moisture/gfs.0p25.2025010200.f003-25.2025010300.f384.grib2.tar')

# %%
for message in grib:
    print(message)
# Out:
# 1:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 3 hrs:from 202501020000
# 2:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 3 hrs:from 202501020000
# 3:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 3 hrs:from 202501020000
# 4:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 3 hrs:from 202501020000
# 5:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 6 hrs:from 202501020000
# 6:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 6 hrs:from 202501020000
# 7:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 6 hrs:from 202501020000
# ...
