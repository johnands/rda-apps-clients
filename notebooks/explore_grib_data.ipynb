# %%
import src.python.rdams_client as rc

dataset_id = 'd084001'
summary = rc.get_summary(dataset_id)
summary.json()
# Out:
# {'status': 'ok',
#  'http_response': 200,
#  'error_messages': [],
#  'data': {'subsetting_available': True,
#   'data': [{'request_type': 'T', 'group_index': 0}]},
#  'contact': 'rdahelp@ucar.edu'}

# %% [markdown]
# ### Parameter overview

# %%
param_response = rc.get_param_summary(dataset_id)
param_data = param_response.json()['data']['data']

param_map = {}
for param in param_data:
    short_name = param['param']
    long_name = param['param_description']
    unit = param.get('units', 'N/A')
    param_map[short_name] = f'{long_name} ({unit})'

for k, v in sorted(param_map.items()): print('{:7} : {}'.format(k, v))
# Out:
# 4LFTX   : Best (4 layer) lifted index (deg K)
# 5WAVH   : 5-wave geopotential height (gpm)
# A PCP   : Total precipitation (kg m^-2)
# ABS V   : Absolute vorticity (s^-1)
# ACPCP   : Convective precipitation (kg m^-2)
# ALBDO   : Albedo (%)
# APTMP   : Apparent temperature (K)
# C WAT   : Cloud water (kg m^-2)
# CAPE    : Convective available potential energy (J kg^-1)
# CDUVB   : Clear sky UV-B downward solar flux (W m^-2)
# CFRZR   : Categorical freezing rain (yes=1; no=0) (N/A)
# CICEP   : Categorical ice pellets (yes=1; no=0) (N/A)
# CIN     : Convective inhibition (J kg^-1)
# CLWMR   : Cloud water mixing ratio (kg kg^-1)
# CNWAT   : Plant canopy surface water (kg m^-2)
# CPOFP   : Percent frozen precipitation (%)
# CPRAT   : Convective precipitation rate (kg m^-2 s^-1)
# CRAIN   : Categorical rain (yes=1; no=0) (N/A)
# CSNOW   : Categorical snow (yes=1; no=0) (N/A)
# CWORK   : Cloud workfunction (J kg^-1)
# DLWRF   : Downward longwave radiation flux (W m^-2)
# DPT     : Dewpoint temperature (K)
# DSWRF   : Downward shortwave radiation flux (W m^-2)
# DUVB    : UV-B downward solar flux (W m^-2)
# DZDT    : Vertical velocity (geometric) (m s^-1)
# FLDCP   : Field capacity (N/A)
# FRICV   : Frictional velocity (m s^-1)
# GFLUX   : Ground heat flux (W m^-2)
# GRLE    : Graupel (kg kg^-1)
# GUST    : Wind speed (gust) (m s^-1)
# H CDC   : High cloud cover (%)
# HGT     : Geopotential height (gpm)
# HINDEX  : Haines index (N/A)
# HLCY    : Storm relative helicity (m^2 s^-2)
# HPBL    : Planetary boundary layer height (m)
# ICAHT   : ICAO standard atmosphere reference height (m)
# ICEC    : Ice cover (fraction)
# ICEG    : Ice growth rate (m s^-1)
# ICETK   : Ice thickness (m)
# ICETMP  : Ice temperature (deg K)
# ICMR    : Ice water mixing ratio (kg kg^-1)
# ICSEV   : Icing severity (N/A)
# L CDC   : Low cloud cover (%)
# LAND    : Land cover (0=sea, 1=land) (Proportion)
# LANDN   : Land-sea coverage (nearest neighbor) [land=1, sea=0] (Proportion)
# LFT X   : Surface lifted index (deg K)
# LHTFL   : Latent heat flux (W m^-2)
# M CDC   : Medium cloud cover (%)
# MSLET   : MSLP (Eta model reduction) (Pa)
# O3MR    : Ozone mixing ratio (kg kg^-1)
# P WAT   : Precipitable water (kg m^-2)
# PEVPR   : Potential evaporation rate (W m^-2)
# PLPL    : Pressure of level from which parcel was lifted (Pa)
# POT     : Potential temperature (K)
# PRATE   : Precipitation rate (kg m^-2 s^-1)
# PRES    : Pressure (Pa)
# PRMSL   : Pressure reduced to MSL (Pa)
# R H     : Relative humidity (%)
# REFC    : Maximum/Composite radar reflectivity (dB)
# REFD    : Derived radar reflectivity (dB)
# RWMR    : Rain water mixing ratio (kg kg^-1)
# SFC R   : Surface roughness (m)
# SHTFL   : Sensible heat flux (W m^-2)
# SNMR    : Snow water mixing ratio (kg kg^-1)
# SNO D   : Snow depth (m)
# SOILL   : Liquid volumetric soil moisture (non-frozen) (N/A)
# SOILW   : Volumetric soil moisture content (N/A)
# SOTYP   : Soil type (N/A)
# SPF H   : Specific humidity (kg kg^-1)
# SUNSD   : Sunshine duration (s)
# T CDC   : Total cloud cover (%)
# T MAX   : Maximum temperature (K)
# T MIN   : Minimum temperature (K)
# TMP     : Temperature (K)
# TOZNE   : Total ozone (Dobson)
# TSOIL   : Soil temperature (K)
# U FLX   : Momentum flux, u-component (N m^-2)
# U GRD   : u-component of wind (m s^-1)
# U-GWD   : Zonal flux of gravity wave stress (N m^-2)
# ULWRF   : Upward longwave radiation flux (W m^-2)
# USTM    : u-component of storm motion (m s^-1)
# USWRF   : Upward shortwave radiation flux (W m^-2)
# V FLX   : Momentum flux, v-component (N m^-2)
# V GRD   : v-component of wind (m s^-1)
# V VEL   : Vertical velocity (pressure) (Pa s^-1)
# V-GWD   : Meridional flux of gravity wave stress (N m^-2)
# VEG     : Vegetation (%)
# VIS     : Visibility (m)
# VRATE   : Ventilation rate (m^2 s^-1)
# VSTM    : v-component of storm motion (m s^-1)
# VW SH   : Vertical speed shear (s^-1)
# WATR    : Water runoff (kg m^-2)
# WEASD   : Water equivalent of accumulated snow depth (kg m^-2)
# WILT    : Wilting point (N/A)

# %%
metadata_response = rc.get_metadata(dataset_id)
metadata = metadata_response.json()['data']['data']

# %% [markdown]
# ### Level overview

# %%
level_map = set([(level['level'], level['level_description']) for param in metadata for level in param['levels']])
for name, description in sorted(level_map): print('{:7} : {}'.format(name, description))
# Out:
# 0DEG    : Level of 0-degree C isotherm
# BCY     : Boundary layer cloud layer
# CCBL    : Convective cloud bottom level
# CCTL    : Convective cloud top level
# CCY     : Convective cloud layer
# CEIL    : Cloud ceiling
# DBLL    : Depth below land surface
# EATM    : Entire atmosphere
# EATM    : Entire atmosphere (considered as a single layer)
# GPML    : Specified altitude above mean sea level
# HCBL    : High cloud bottom level
# HCTL    : High cloud top level
# HCY     : High cloud layer
# HTFL    : Highest tropospheric freezing level
# HTGL    : Specified height above ground
# HYBL    : Hybrid level
# ISBL    : Isobaric surface
# LCBL    : Low cloud bottom level
# LCTL    : Low cloud top level
# LCY     : Low cloud layer
# MCBL    : Middle cloud bottom level
# MCTL    : Middle cloud top level
# MCY     : Middle cloud layer
# MSL     : Mean sea level
# MWSL    : Maximum wind level
# NTAT    : Nominal top of atmosphere
# PBLRI   : Planetary boundary layer
# PVL     : Potential vorticity surface
# SFC     : Ground or water surface
# SIGL    : Sigma level
# SPDL    : Level at specified pressure difference from ground to level
# TRO     : Tropopause

# %%
import pandas as pd
from natsort import natsort_keygen

levels = list(set([(level['level'], level['level_description'], level['level_value']) for param in metadata for level in param['levels']]))
levels = pd.DataFrame.from_records(levels, columns=['level_name', 'level_description', 'level_value'])
pd.options.display.max_rows = None
levels.sort_values(by=['level_name', 'level_value'], key=natsort_keygen()).reset_index(drop=True)
# Out:
#     level_name                                  level_description level_value
# 0         0DEG                       Level of 0-degree C isotherm           0
# 1          BCY                         Boundary layer cloud layer           0
# 2         CCBL                      Convective cloud bottom level           0
# 3         CCTL                         Convective cloud top level           0
# 4          CCY                             Convective cloud layer           0
# 5         CEIL                                      Cloud ceiling           0
# 6         DBLL                           Depth below land surface       0.1,0
# 7         DBLL                           Depth below land surface     0.4,0.1
# 8         DBLL                           Depth below land surface       1,0.4
# 9         DBLL                           Depth below land surface         2,1
# 10        EATM   Entire atmosphere (considered as a single layer)           0
# 11        EATM                                  Entire atmosphere           0
# 12        GPML            Specified altitude above mean sea level          10
# 13        GPML            Specified altitude above mean sea level         305
# 14        GPML            Specified altitude above mean sea level         457
# 15        GPML            Specified altitude above mean sea level         610
# 16        GPML            Specified altitude above mean sea level         914
# 17        GPML            Specified altitude above mean sea level        1829
# 18        GPML            Specified altitude above mean sea level        2743
# 19        GPML            Specified altitude above mean sea level        3658
# 20        GPML            Specified altitude above mean sea level        4572
# 21        HCBL                            High cloud bottom level           0
# 22        HCTL                               High cloud top level           0
# 23         HCY                                   High cloud layer           0
# 24        HTFL                Highest tropospheric freezing level           0
# 25        HTGL                      Specified height above ground      0,3000
# 26        HTGL                      Specified height above ground      0,6000
# 27        HTGL                      Specified height above ground           2
# 28        HTGL                      Specified height above ground          10
# 29        HTGL                      Specified height above ground          20
# 30        HTGL                      Specified height above ground          30
# 31        HTGL                      Specified height above ground          40
# 32        HTGL                      Specified height above ground          50
# 33        HTGL                      Specified height above ground          80
# 34        HTGL                      Specified height above ground         100
# 35        HTGL                      Specified height above ground        1000
# 36        HTGL                      Specified height above ground        4000
# 37        HYBL                                       Hybrid level           1
# 38        HYBL                                       Hybrid level           2
# 39        ISBL                                   Isobaric surface        0.01
# 40        ISBL                                   Isobaric surface         0.1
# 41        ISBL                                   Isobaric surface         0.2
# 42        ISBL                                   Isobaric surface        0.02
# 43        ISBL                                   Isobaric surface        0.04
# 44        ISBL                                   Isobaric surface         0.4
# 45        ISBL                                   Isobaric surface         0.7
# 46        ISBL                                   Isobaric surface        0.07
# 47        ISBL                                   Isobaric surface           1
# 48        ISBL                                   Isobaric surface           2
# 49        ISBL                                   Isobaric surface           3
# 50        ISBL                                   Isobaric surface           5
# 51        ISBL                                   Isobaric surface           7
# 52        ISBL                                   Isobaric surface          10
# 53        ISBL                                   Isobaric surface          15
# 54        ISBL                                   Isobaric surface          20
# 55        ISBL                                   Isobaric surface          30
# 56        ISBL                                   Isobaric surface          40
# 57        ISBL                                   Isobaric surface          50
# 58        ISBL                                   Isobaric surface          70
# 59        ISBL                                   Isobaric surface         100
# 60        ISBL                                   Isobaric surface         125
# 61        ISBL                                   Isobaric surface         150
# 62        ISBL                                   Isobaric surface         175
# 63        ISBL                                   Isobaric surface         200
# 64        ISBL                                   Isobaric surface         225
# 65        ISBL                                   Isobaric surface         250
# 66        ISBL                                   Isobaric surface         275
# 67        ISBL                                   Isobaric surface         300
# 68        ISBL                                   Isobaric surface         325
# 69        ISBL                                   Isobaric surface         350
# 70        ISBL                                   Isobaric surface         375
# 71        ISBL                                   Isobaric surface         400
# 72        ISBL                                   Isobaric surface         425
# 73        ISBL                                   Isobaric surface         450
# 74        ISBL                                   Isobaric surface         475
# 75        ISBL                                   Isobaric surface         500
# 76        ISBL                                   Isobaric surface         525
# 77        ISBL                                   Isobaric surface         550
# 78        ISBL                                   Isobaric surface         575
# 79        ISBL                                   Isobaric surface         600
# 80        ISBL                                   Isobaric surface         625
# 81        ISBL                                   Isobaric surface         650
# 82        ISBL                                   Isobaric surface         675
# 83        ISBL                                   Isobaric surface         700
# 84        ISBL                                   Isobaric surface         725
# 85        ISBL                                   Isobaric surface         750
# 86        ISBL                                   Isobaric surface         775
# 87        ISBL                                   Isobaric surface         800
# 88        ISBL                                   Isobaric surface         825
# 89        ISBL                                   Isobaric surface         850
# 90        ISBL                                   Isobaric surface         875
# 91        ISBL                                   Isobaric surface         900
# 92        ISBL                                   Isobaric surface         925
# 93        ISBL                                   Isobaric surface         950
# 94        ISBL                                   Isobaric surface         975
# 95        ISBL                                   Isobaric surface        1000
# 96        LCBL                             Low cloud bottom level           0
# 97        LCTL                                Low cloud top level           0
# 98         LCY                                    Low cloud layer           0
# 99        MCBL                          Middle cloud bottom level           0
# 100       MCTL                             Middle cloud top level           0
# 101        MCY                                 Middle cloud layer           0
# 102        MSL                                     Mean sea level           0
# 103       MWSL                                 Maximum wind level           0
# 104       NTAT                          Nominal top of atmosphere           0
# 105      PBLRI                           Planetary boundary layer           0
# 106        PVL                        Potential vorticity surface         500
# 107        PVL                        Potential vorticity surface        1000
# 108        PVL                        Potential vorticity surface        1500
# 109        PVL                        Potential vorticity surface        2000
# 110        PVL                        Potential vorticity surface        -500
# 111        PVL                        Potential vorticity surface       -1000
# 112        PVL                        Potential vorticity surface       -1500
# 113        PVL                        Potential vorticity surface       -2000
# 114        SFC                            Ground or water surface           0
# 115       SIGL                                        Sigma level   0.72,0.44
# 116       SIGL                                        Sigma level   0.94,0.72
# 117       SIGL                                        Sigma level       0.995
# 118       SIGL                                        Sigma level      1,0.33
# 119       SIGL                                        Sigma level      1,0.44
# 120       SPDL  Level at specified pressure difference from gr...        0,30
# 121       SPDL  Level at specified pressure difference from gr...        0,90
# 122       SPDL  Level at specified pressure difference from gr...       0,180
# 123       SPDL  Level at specified pressure difference from gr...       0,255
# 124       SPDL  Level at specified pressure difference from gr...       30,60
# 125       SPDL  Level at specified pressure difference from gr...       60,90
# 126       SPDL  Level at specified pressure difference from gr...      90,120
# 127       SPDL  Level at specified pressure difference from gr...     120,150
# 128       SPDL  Level at specified pressure difference from gr...     150,180
# 129        TRO                                         Tropopause           0

# %% [markdown]
# ### Parameter example

# %%
from natsort import natsorted

parameter_vars = list(filter(lambda x: x['param'] == 'SOILW', metadata))
products = set([item['product'] for item in parameter_vars])
for product in natsorted(products): print(product)
# Out:
# 3-hour Forecast
# 6-hour Forecast
# 9-hour Forecast
# 12-hour Forecast
# 15-hour Forecast
# 18-hour Forecast
# 21-hour Forecast
# 24-hour Forecast
# 27-hour Forecast
# 30-hour Forecast
# 33-hour Forecast
# 36-hour Forecast
# 39-hour Forecast
# 42-hour Forecast
# 45-hour Forecast
# 48-hour Forecast
# 51-hour Forecast
# 54-hour Forecast
# 57-hour Forecast
# 60-hour Forecast
# 63-hour Forecast
# 66-hour Forecast
# 69-hour Forecast
# 72-hour Forecast
# 75-hour Forecast
# 78-hour Forecast
# 81-hour Forecast
# 84-hour Forecast
# 87-hour Forecast
# 90-hour Forecast
# 93-hour Forecast
# 96-hour Forecast
# 99-hour Forecast
# 102-hour Forecast
# 105-hour Forecast
# 108-hour Forecast
# 111-hour Forecast
# 114-hour Forecast
# 117-hour Forecast
# 120-hour Forecast
# 123-hour Forecast
# 126-hour Forecast
# 129-hour Forecast
# 132-hour Forecast
# 135-hour Forecast
# 138-hour Forecast
# 141-hour Forecast
# 144-hour Forecast
# 147-hour Forecast
# 150-hour Forecast
# 153-hour Forecast
# 156-hour Forecast
# 159-hour Forecast
# 162-hour Forecast
# 165-hour Forecast
# 168-hour Forecast
# 171-hour Forecast
# 174-hour Forecast
# 177-hour Forecast
# 180-hour Forecast
# 183-hour Forecast
# 186-hour Forecast
# 189-hour Forecast
# 192-hour Forecast
# 195-hour Forecast
# 198-hour Forecast
# 201-hour Forecast
# 204-hour Forecast
# 207-hour Forecast
# 210-hour Forecast
# 213-hour Forecast
# 216-hour Forecast
# 219-hour Forecast
# 222-hour Forecast
# 225-hour Forecast
# 228-hour Forecast
# 231-hour Forecast
# 234-hour Forecast
# 237-hour Forecast
# 240-hour Forecast
# 246-hour Forecast
# 252-hour Forecast
# 258-hour Forecast
# 264-hour Forecast
# 270-hour Forecast
# 276-hour Forecast
# 282-hour Forecast
# 288-hour Forecast
# 294-hour Forecast
# 300-hour Forecast
# 306-hour Forecast
# 312-hour Forecast
# 318-hour Forecast
# 324-hour Forecast
# 330-hour Forecast
# 336-hour Forecast
# 342-hour Forecast
# 348-hour Forecast
# 354-hour Forecast
# 360-hour Forecast
# 366-hour Forecast
# 372-hour Forecast
# 378-hour Forecast
# 384-hour Forecast
# Analysis

# %%
parameter_product = list(filter(lambda x: x['product'] == '3-hour Forecast', parameter_vars))[0]
levels = list(set([(level_dict['level'], level_dict['level_description'], level_dict['level_value'], level_dict.get("units", "N/A")) for level_dict in parameter_product['levels']]))
levels = pd.DataFrame.from_records(levels, columns=['level_name', 'level_description', 'level_value', 'units'])
pd.options.display.max_rows = None
levels.sort_values(by=['level_name', 'level_value'], key=natsort_keygen()).reset_index(drop=True)
# Out:
#   level_name         level_description level_value units
# 0       DBLL  Depth below land surface       0.1,0     m
# 1       DBLL  Depth below land surface     0.4,0.1     m
# 2       DBLL  Depth below land surface       1,0.4     m
# 3       DBLL  Depth below land surface         2,1     m

# %%
metadata[0]
# Out:
# {'param': 'T CDC',
#  'param_description': 'Total cloud cover',
#  'start_date': 201906121200,
#  'end_date': 202501111200,
#  'native_format': 'WMO_GRIB2',
#  'gridproj': 'latLon',
#  'griddef': '1440:721:90N:0E:90S:359.75E:0.25:0.25',
#  'level': None,
#  'units': '%',
#  'GCMD_uuid': 'acb52274-6c0d-4241-a979-3fa3efca6702',
#  'product': 'Analysis',
#  'levels': [{'units': 'mbar',
#    'level_value': '1000',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '975',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '950',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '925',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '900',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '850',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '800',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '750',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '700',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '650',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '600',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '550',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '500',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '450',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '400',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '350',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '300',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '250',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '200',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '150',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '100',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'units': 'mbar',
#    'level_value': '50',
#    'level_description': 'Isobaric surface',
#    'level': 'ISBL'},
#   {'level_value': '0',
#    'level_description': 'Entire atmosphere',
#    'level': 'EATM'}]}
